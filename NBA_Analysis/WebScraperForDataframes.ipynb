# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import pandas as pd
from io import StringIO
import os

# %%
# setting the years needed and url to look at player
year = 2025
url_start = 'https://www.basketball-reference.com/players/j/{}01/gamelog/2025'

# %%
# path to create the GameLog folder if it didn't exist
main_folder = "GameLogs" 
if not os.path.exists(main_folder):
    os.makedir(main_folder)

# %%
# get full name from input
full_name = input("Enter players name (firstname lastname): ").strip()
# split the name into first name last name
split_name = full_name.split()
if len(split_name) != 2: # raise Error if theres less than 1 name or more than 2
    raise ValueError("Please enter both first and last name. Make sure to include any '-' !")

first_name = split_name[0] 
last_name = split_name[1]
player_name = last_name[:5].lower() + first_name[:2].lower() # formats the name so the website can use it. Lebron James -> jamesle
# Out:
# Enter players name (firstname lastname):  Jamal Murray

# %%
# looks up the corresponding year and creates/overwrites the html file in my JokicGameLogs folder
url = url_start.format(player_name)
response = requests.get(url)
# to write a file for each 'x'
file_path = f"GameLogs/{player_name}GameLog.html"
with open(file_path, "w+", encoding="utf-8") as f:
    f.write(response.text)

# %%
with open(f"GameLogs/{player_name}GameLog.html", encoding="utf-8") as f:
    page = f.read()
    soup = BeautifulSoup(page, "html.parser")
    stats_table = soup.find(id="pgl_basic")
    stats_df = pd.read_html(StringIO(str(stats_table)))[0]
    df = stats_df

# %%
# Drop rows of fluff where the index + 1 is divisible by 20 (21, 41, 61, ...)
if 20 in df.index:
    df = df.drop(20)
if 41 in df.index:
    df = df.drop(41)
if 62 in df.index:
    df = df.drop(62)
if 83 in df.index:
    df = df.drop(83)

# %% [markdown]
# ##### DATAFRAME IS READY
# Now lets clean up column names and nulls

# %%
# drop the 'Rk' column so we can use our index col instead
if 'Rk' in df.columns:
    df = df.drop(columns=['Rk'])

# drop null rows for subset df
game_only_df = df.dropna(subset=['G'])
# fill null Game played values with "DNP"
df.fillna({"G":"DNP"}, inplace=True)

# %%
# name all colums correctly
df.rename(columns={'Unnamed: 5': 'Location'}, inplace=True)
df.rename(columns={'Unnamed: 7': 'WLSpread'}, inplace=True)
df.fillna({'Location':'Home'}, inplace=True)
df.replace({'@': 'Away'}, inplace=True)

# %%
dfs = {}
dfs[player_name] = df

# %%
df
# Out:
#       G        Date     Age   Tm Location  Opp WLSpread        GS        MP  \
# 0     1  2024-10-24  27-244  DEN     Home  OKC  L (-15)         1     38:27
# 1     2  2024-10-26  27-246  DEN     Home  LAC   L (-5)         1     36:51
# 2     3  2024-10-28  27-248  DEN     Away  TOR   W (+2)         1     39:43
# 3     4  2024-10-29  27-249  DEN     Away  BRK   W (+5)         1     36:44
# 4     5  2024-11-01  27-252  DEN     Away  MIN   L (-3)         1     22:16
# 5   DNP  2024-11-02  27-253  DEN     Home  UTA  W (+26)  Inactive  Inactive
# 6   DNP  2024-11-04  27-255  DEN     Home  TOR   W (+2)  Inactive  Inactive
# 7   DNP  2024-11-06  27-257  DEN     Home  OKC   W (+2)  Inactive  Inactive
inactive  ...  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 6   Inactive  ...  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 7   Inactive  ...  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 8          9  ...         4         4         6         0         0         4
# 9          7  ...         1         1         6         0         0         2
# 10         6  ...         6         6         8         2         0         0
# 11         6  ...         5         6         7         3         2         6
# 12        10  ...         3         4         6         3         2         3
# 13         4  ...         5         5        11         0         3         3
# 14         5  ...         5         5         5         1         0         2
# 15         6  ...         3         4         7         1         0         0
# 16        10  ...         2         4         8         4         0         1
# 17         7  ...         0         0         7         1         0         3
# 18         4  ...         3         3         7         1         3         1
# 19         7  ...         3         4         6         1         0         1
# 21  Inactive  ...  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 22  Inactive  ...  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 23         8  ...         5         5         3         4         1         6
# 24        11  ...         2         2         6         0         1         1
# 25         9  ...         3         3        10         3         0         1
# 26         9  ...         7         8         4         3         1         6
# 27  Inactive  ...  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 28         4  ...         6         6         6         0         0         4
# 29        10  ...         3         3        11         2         0         4
# 30        12  ...         4         5         4         1         3         1
# 31         7  ...         3         4        10         2         1         3
# 32         6  ...         2         3         2         2         1         2
# 33         6  ...         3         4         7         0         0         2
# 34         6  ...         6         6         6         5         1         1
# 35         8  ...         2         4         4         2         0         1
# 36         7  ...         3         3         9         1         1         2
# 37         2  ...         0         0         3         1         0         3
# 38         7  ...         2         2         2         0         0         1
# 39        18  ...         2         2         6         2         0         5
# 40         8  ...         4         4         5         0         0         5
# 42        12  ...         5         7         8         3         1         0
# 43         8  ...         1         2         4         1         0         1
#
#           PF       PTS      GmSc       +/-
# 0          2        12       8.1        -2
# 1          1        22      18.7        +6
# 2          2        17      13.6        +8
# 3          3        24      13.9        +3
# 4          0         6       5.6        +8
# 5   Inactive  Inactive  Inactive  Inactive
# 6   Inactive  Inactive  Inactive  Inactive
# 7   Inactive  Inactive  Inactive  Inactive
# 8          0        28      21.1       +28
# 9          3        18       9.0       +15
# 10         1        16      16.2         0
# 11         3        13       9.2        -3
# 12         2        27      23.0       +18
# 13         3        14      11.5         0
# 14         2        14       9.2       +20
# 15         1        20      19.6       -13
# 16         2        22      23.2       +18
# 17         1        18      14.9        -1
# 18         3        12      11.9        +4
# 19         0        19      16.0       -10
# 21  Inactive  Inactive  Inactive  Inactive
# 22  Inactive  Inactive  Inactive  Inactive
# 23         2        20      13.5       +18
# 24         2        28      17.9       +10
# 25         3        24      22.6        +1
# 26         2        27      19.4        -5
# 27  Inactive  Inactive  Inactive  Inactive
# 28         1        13       9.2       -16
# 29         3        27      22.4        -9
# 30         1        34      30.1       +24
# 31         2        20      18.4        -9
# 32         1        21      16.6       +11
# 33         1        14       8.6        -7
# 34         3        13      13.0        +4
# 35         3        19      14.9        -3
# 36         1        21      21.2       +24
# 37         0         7       4.4         0
# 38         4        17       5.8        -5
# 39         0        45      35.8       +14
# 40         2        22      14.3       -17
# 42         0        30      30.2       +19
# 43         2        19      14.0       +13
#
# [42 rows x 29 columns]
